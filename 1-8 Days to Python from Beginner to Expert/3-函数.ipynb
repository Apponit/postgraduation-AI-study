# %%
def len1(str1):
    """
    求字符串的长度
    :param str1: 形参
    :return: 长度
    """
    count=0
    for i in str1:
        count+=1
    return count
print(len1("123456"))
# Out:
# 6

# %%
def function():
    print(f"welcome!\n请出核酸码！")

function()
# Out:
# welcome!
# 请出核酸码！

# %%
def check(temp):
    if temp<=37.5:
        print(f"体温{temp},welcome!")
    else:
        print(f"体温{temp}，sorry!")
check(100)
# Out:
# 体温100，sorry!

# %%
def add(a,b):
    return a+b
print(add(100,200))
# Out:
# 300

# %%
def function(a,b):
    """
    函数说明
    :param a:形参说明
    :param b:形参说明
    :return:返回值说明
    """
    return a+b
a=1
b=2
function(a,b)

# %%
def f1():
    print("---1---")
    f2()
def f2():
    print("---2---")

    print("---3---")
f1()
# Out:
# ---1---
# ---2---
# ---3---

# %%
num=100
def f1():
    print(f"f1{num}")
def f2():
    num=500
    print(f"f2{num}")
f1()# 100
f2()# 500
print(num)# 100，没有修改，是因为f2中的num只是和全局变量num名字相同的函数内形参，只是给形参赋值，没有全局变量。
# Out:
# f1100
# f2500
# 100

# %%
money=5000000
name=""
def check():
    print(f"{name}，你好，你的余额为：{money}")
def add(n):
    global money
    money+=n
    print(f"{name}，你好，你的存款{n}成功\n{name}，你好，你的余额：{money}元")


while 1:
